# %% [markdown]
# # Round40 9338 Blend
#
# Notebook para correr a Round40 focada no `9338.png`.
#
# A estrategia e misturar a cor/semantica da Round38 com a pose lateral da Round39, evitando termos que criaram falhas (`dragon`, `wing`, `rodent`).

# %%
from pathlib import Path
import json
import os
import subprocess
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src" / "search_multiseed_validate.py").exists():
    PROJECT_ROOT = Path("C:\\Users\\tugap\\Desktop\\Universidade\\Masters2\u00baAno\\IAG\\ProjetoCunha\\Projeto2")

SRC_DIR = PROJECT_ROOT / "src"
PROMPT_BANK = PROJECT_ROOT / "prompts" / "refinement_round40_9338_blend.json"
TARGETS_DIR = PROJECT_ROOT / "TP2-students" / "students" / "tp2-chosen"
OUTPUT_DIR = PROJECT_ROOT / "TP2-students" / "students" / "outputs"

PYTHON_CANDIDATES = [
    PROJECT_ROOT / ".venv_win" / "Scripts" / "python.exe",
    Path("C:\\Users\\tugap\\Desktop\\Universidade\\Masters2\u00baAno\\IAG\\Projeto 2\\.venv\\Scripts\\python.exe"),
    Path(sys.executable),
]

def has_module(python_exe, module_name):
    if not Path(python_exe).exists():
        return False
    result = subprocess.run(
        [str(python_exe), "-c", f"import {module_name}"],
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True,
        encoding="utf-8",
        errors="replace",
    )
    return result.returncode == 0

PYTHON_EXE = None
for candidate in PYTHON_CANDIDATES:
    if has_module(candidate, "diffusers"):
        PYTHON_EXE = candidate
        break

if PYTHON_EXE is None:
    raise RuntimeError("No Python with diffusers found. Create .venv_win and install requirements.txt")

print("Project root:", PROJECT_ROOT)
print("Notebook kernel:", sys.executable)
print("Render/search Python:", PYTHON_EXE)
print("Prompt bank:", PROMPT_BANK)
assert (SRC_DIR / "generate_round40_9338_blend.py").exists()
assert (SRC_DIR / "search_multiseed_validate.py").exists()
assert TARGETS_DIR.exists()
# Out:
# Project root: c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2
# Notebook kernel: c:\Users\tugap\AppData\Local\Programs\Python\Python311\python.exe
# Render/search Python: C:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\Projeto 2\.venv\Scripts\python.exe
# Prompt bank: c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2\prompts\refinement_round40_9338_blend.json

# %% [markdown]
# ## Configuracao

# %%
RUN_MODE = "focused"  # smoke | focused | deep

MODES = {
    "smoke": {
        "identity": "round40_9338_smoke",
        "limit_per_target": 24,
        "top_k": 4,
        "stage1_save_k": 8,
        "validation_top_n": 6,
        "ensemble_per_metric": 2,
        "seed_offsets": [1],
    },
    "focused": {
        "identity": "round40_9338_blend",
        "limit_per_target": None,
        "top_k": 12,
        "stage1_save_k": 40,
        "validation_top_n": 28,
        "ensemble_per_metric": 7,
        "seed_offsets": [1, 2, 3],
    },
    "deep": {
        "identity": "round40_9338_blend_deep",
        "limit_per_target": None,
        "top_k": 16,
        "stage1_save_k": 56,
        "validation_top_n": 40,
        "ensemble_per_metric": 9,
        "seed_offsets": [1, 2, 3, 4, 5],
    },
}

config = MODES[RUN_MODE]
print("Selected mode:", RUN_MODE)
print(json.dumps(config, indent=2))
# Out:
# Selected mode: focused
# {
#   "identity": "round40_9338_blend",
#   "limit_per_target": null,
#   "top_k": 12,
#   "stage1_save_k": 40,
#   "validation_top_n": 28,
#   "ensemble_per_metric": 7,
#   "seed_offsets": [
#     1,
#     2,
#     3
#   ]
# }

# %% [markdown]
# ## Gerar prompts

# %%
cmd = [str(PYTHON_EXE), str(SRC_DIR / "generate_round40_9338_blend.py"), "--output", str(PROMPT_BANK)]
print("Running:", " ".join(cmd))
subprocess.run(cmd, cwd=PROJECT_ROOT, check=True)

data = json.loads(PROMPT_BANK.read_text(encoding="utf-8"))
print({target: len(entries) for target, entries in data.items()})
# Out:
# Running: C:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\Projeto 2\.venv\Scripts\python.exe c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2\src\generate_round40_9338_blend.py --output c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2\prompts\refinement_round40_9338_blend.json
# {'9338.png': 760}

# %% [markdown]
# ## Correr pesquisa

# %%
args = [
    str(PYTHON_EXE),
    str(SRC_DIR / "search_multiseed_validate.py"),
    "--prompts", str(PROMPT_BANK),
    "--targets", str(TARGETS_DIR),
    "--output-dir", str(OUTPUT_DIR),
    "--identity", config["identity"],
    "--only", "9338.png",
    "--top-k", str(config["top_k"]),
    "--stage1-save-k", str(config["stage1_save_k"]),
    "--validation-top-n", str(config["validation_top_n"]),
    "--ensemble-per-metric", str(config["ensemble_per_metric"]),
    "--seed-offsets", *[str(seed) for seed in config["seed_offsets"]],
    "--offline",
    "--disable-progress-bar",
    "--maxstack-scoring",
]
if config["limit_per_target"] is not None:
    args.extend(["--limit-per-target", str(config["limit_per_target"])])

env = os.environ.copy()
env["PYTHONIOENCODING"] = "utf-8"

print("Running:")
print(" ".join(args))
process = subprocess.Popen(
    args,
    cwd=PROJECT_ROOT,
    env=env,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    encoding="utf-8",
    errors="replace",
    bufsize=1,
)
for line in process.stdout:
    print(line, end="")
return_code = process.wait()
if return_code != 0:
    raise RuntimeError(f"Search failed with exit code {return_code}")
print("Finished successfully")
# Out:
# Running:
# C:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\Projeto 2\.venv\Scripts\python.exe c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2\src\search_multiseed_validate.py --prompts c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2\prompts\refinement_round40_9338_blend.json --targets c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2\TP2-students\students\tp2-chosen --output-dir c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2\TP2-students\students\outputs --identity round40_9338_blend --only 9338.png --top-k 12 --stage1-save-k 40 --validation-top-n 28 --ensemble-per-metric 7 --seed-offsets 1 2 3 --offline --disable-progress-bar --maxstack-scoring
# Couldn't connect to the Hub: Cannot reach https://huggingface.co/api/models/SimianLuo/LCM_Dreamshaper_v7: offline mode is enabled. To disable it, please unset the `HF_HUB_OFFLINE` environment variable..
# Will try to load from local cache.
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading pipeline components...:  43%|████▎     | 3/7 [00:00<00:00, 24.87it/s]
# Loading pipeline components...:  86%|████████▌ | 6/7 [00:03<00:00,  1.43it/s]
# Loading pipeline components...:  86%|████████▌ | 6/7 [00:23<00:00,  1.43it/s]
# Loading pipeline components...: 100%|██████████| 7/7 [00:25<00:00,  5.26s/it]
# Loading pipeline components...: 100%|██████████| 7/7 [00:25<00:00,  3.59s/it]
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# C:\Users\tugap\AppData\Roaming\Python\Python311\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\tugap\AppData\Roaming\Python\Python311\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: C:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\Projeto 2\.venv\Lib\site-packages\lpips\weights\v0.1\alex.pth
# C:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\Projeto 2\.venv\Lib\site-packages\lpips\lpips.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(model_path, map_location='cpu'), strict=False)
# 00:17:59 [INFO] Run directory: c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2\TP2-students\students\outputs\20260603-001759_round40_9338_blend
# 00:17:59 [INFO] Run directory: c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2\TP2-students\students\outputs\20260603-001759_round40_9338_blend
# 00:17:59 [INFO] Stage 1 fixed-seed search, then validating top candidates with offsets: [1, 2, 3]
# 00:17:59 [INFO] Stage 1 fixed-seed search, then validating top candidates with offsets: [1, 2, 3]
# 00:18:02 [INFO] [stage1 1/760] 9338.png #001
# 00:18:02 [INFO] [stage1 1/760] 9338.png #001
# 00:18:42 [INFO] [stage1 10/760] 9338.png #010
# 00:18:42 [INFO] [stage1 10/760] 9338.png #010
# 00:19:25 [INFO] [stage1 20/760] 9338.png #020
# 00:19:25 [INFO] [stage1 20/760] 9338.png #020
# 00:20:09 [INFO] [stage1 30/760] 9338.png #030
# 00:20:09 [INFO] [stage1 30/760] 9338.png #030
# 00:20:52 [INFO] [stage1 40/760] 9338.png #040
# 00:20:52 [INFO] [stage1 40/760] 9338.png #040
# 00:21:34 [INFO] [stage1 50/760] 9338.png #050
# 00:21:34 [INFO] [stage1 50/760] 9338.png #050
# 00:22:19 [INFO] [stage1 60/760] 9338.png #060
# 00:22:19 [INFO] [stage1 60/760] 9338.png #060
# 00:23:06 [INFO] [stage1 70/760] 9338.png #070
# 00:23:06 [INFO] [stage1 70/760] 9338.png #070
# 00:23:51 [INFO] [stage1 80/760] 9338.png #080
# 00:23:51 [INFO] [stage1 80/760] 9338.png #080
# 00:24:37 [INFO] [stage1 90/760] 9338.png #090
# 00:24:37 [INFO] [stage1 90/760] 9338.png #090
# 00:25:18 [INFO] [stage1 100/760] 9338.png #100
# 00:25:18 [INFO] [stage1 100/760] 9338.png #100
# 00:25:59 [INFO] [stage1 110/760] 9338.png #110
# 00:25:59 [INFO] [stage1 110/760] 9338.png #110
# 00:26:41 [INFO] [stage1 120/760] 9338.png #120
# 00:26:41 [INFO] [stage1 120/760] 9338.png #120
# 00:27:23 [INFO] [stage1 130/760] 9338.png #130
# 00:27:23 [INFO] [stage1 130/760] 9338.png #130
# 00:28:06 [INFO] [stage1 140/760] 9338.png #140
# 00:28:06 [INFO] [stage1 140/760] 9338.png #140
# 00:28:47 [INFO] [stage1 150/760] 9338.png #150
# 00:28:47 [INFO] [stage1 150/760] 9338.png #150
# 00:29:27 [INFO] [stage1 160/760] 9338.png #160
# 00:29:27 [INFO] [stage1 160/760] 9338.png #160
# 00:30:06 [INFO] [stage1 170/760] 9338.png #170
# 00:30:06 [INFO] [stage1 170/760] 9338.png #170
# 00:30:46 [INFO] [stage1 180/760] 9338.png #180
# 00:30:46 [INFO] [stage1 180/760] 9338.png #180
# 00:31:25 [INFO] [stage1 190/760] 9338.png #190
# 00:31:25 [INFO] [stage1 190/760] 9338.png #190
# 00:32:05 [INFO] [stage1 200/760] 9338.png #200
# 00:32:05 [INFO] [stage1 200/760] 9338.png #200
# 00:32:44 [INFO] [stage1 210/760] 9338.png #210
# 00:32:44 [INFO] [stage1 210/760] 9338.png #210
# 00:33:24 [INFO] [stage1 220/760] 9338.png #220
# 00:33:24 [INFO] [stage1 220/760] 9338.png #220
# 00:34:02 [INFO] [stage1 230/760] 9338.png #230
# 00:34:02 [INFO] [stage1 230/760] 9338.png #230
# 00:34:39 [INFO] [stage1 240/760] 9338.png #240
# 00:34:39 [INFO] [stage1 240/760] 9338.png #240
# 00:35:15 [INFO] [stage1 250/760] 9338.png #250
# 00:35:15 [INFO] [stage1 250/760] 9338.png #250
# 00:35:53 [INFO] [stage1 260/760] 9338.png #260
# 00:35:53 [INFO] [stage1 260/760] 9338.png #260
# 00:36:32 [INFO] [stage1 270/760] 9338.png #270
# 00:36:32 [INFO] [stage1 270/760] 9338.png #270
# 00:37:09 [INFO] [stage1 280/760] 9338.png #280
# 00:37:09 [INFO] [stage1 280/760] 9338.png #280
# 00:37:46 [INFO] [stage1 290/760] 9338.png #290
# 00:37:46 [INFO] [stage1 290/760] 9338.png #290
# 00:38:21 [INFO] [stage1 300/760] 9338.png #300
# 00:38:21 [INFO] [stage1 300/760] 9338.png #300
# 00:38:57 [INFO] [stage1 310/760] 9338.png #310
# 00:38:57 [INFO] [stage1 310/760] 9338.png #310
# 00:39:33 [INFO] [stage1 320/760] 9338.png #320
# 00:39:33 [INFO] [stage1 320/760] 9338.png #320
# 00:40:08 [INFO] [stage1 330/760] 9338.png #330
# 00:40:08 [INFO] [stage1 330/760] 9338.png #330
# 00:40:45 [INFO] [stage1 340/760] 9338.png #340
# 00:40:45 [INFO] [stage1 340/760] 9338.png #340
# 00:41:22 [INFO] [stage1 350/760] 9338.png #350
# 00:41:22 [INFO] [stage1 350/760] 9338.png #350
# 00:41:59 [INFO] [stage1 360/760] 9338.png #360
# 00:41:59 [INFO] [stage1 360/760] 9338.png #360
# 00:42:36 [INFO] [stage1 370/760] 9338.png #370
# 00:42:36 [INFO] [stage1 370/760] 9338.png #370
# 00:43:12 [INFO] [stage1 380/760] 9338.png #380
# 00:43:12 [INFO] [stage1 380/760] 9338.png #380
# 00:43:46 [INFO] [stage1 390/760] 9338.png #390
# 00:43:46 [INFO] [stage1 390/760] 9338.png #390
# 00:44:22 [INFO] [stage1 400/760] 9338.png #400
# 00:44:22 [INFO] [stage1 400/760] 9338.png #400
# 00:44:56 [INFO] [stage1 410/760] 9338.png #410
# 00:44:56 [INFO] [stage1 410/760] 9338.png #410
# 00:45:31 [INFO] [stage1 420/760] 9338.png #420
# 00:45:31 [INFO] [stage1 420/760] 9338.png #420
# 00:46:06 [INFO] [stage1 430/760] 9338.png #430
# 00:46:06 [INFO] [stage1 430/760] 9338.png #430
# 00:46:41 [INFO] [stage1 440/760] 9338.png #440
# 00:46:41 [INFO] [stage1 440/760] 9338.png #440
# 00:47:15 [INFO] [stage1 450/760] 9338.png #450
# 00:47:15 [INFO] [stage1 450/760] 9338.png #450
# 00:47:50 [INFO] [stage1 460/760] 9338.png #460
# 00:47:50 [INFO] [stage1 460/760] 9338.png #460
# 00:48:24 [INFO] [stage1 470/760] 9338.png #470
# 00:48:24 [INFO] [stage1 470/760] 9338.png #470
# 00:49:09 [INFO] [stage1 480/760] 9338.png #480
# 00:49:09 [INFO] [stage1 480/760] 9338.png #480
# 00:49:55 [INFO] [stage1 490/760] 9338.png #490
# 00:49:55 [INFO] [stage1 490/760] 9338.png #490
# 00:50:39 [INFO] [stage1 500/760] 9338.png #500
# 00:50:39 [INFO] [stage1 500/760] 9338.png #500
# 00:51:25 [INFO] [stage1 510/760] 9338.png #510
# 00:51:25 [INFO] [stage1 510/760] 9338.png #510
# 00:52:10 [INFO] [stage1 520/760] 9338.png #520
# 00:52:10 [INFO] [stage1 520/760] 9338.png #520
# 00:52:54 [INFO] [stage1 530/760] 9338.png #530
# 00:52:54 [INFO] [stage1 530/760] 9338.png #530
# 00:53:39 [INFO] [stage1 540/760] 9338.png #540
# 00:53:39 [INFO] [stage1 540/760] 9338.png #540
# 00:54:24 [INFO] [stage1 550/760] 9338.png #550
# 00:54:24 [INFO] [stage1 550/760] 9338.png #550
# 00:55:09 [INFO] [stage1 560/760] 9338.png #560
# 00:55:09 [INFO] [stage1 560/760] 9338.png #560
# 00:55:52 [INFO] [stage1 570/760] 9338.png #570
# 00:55:52 [INFO] [stage1 570/760] 9338.png #570
# 00:56:34 [INFO] [stage1 580/760] 9338.png #580
# 00:56:34 [INFO] [stage1 580/760] 9338.png #580
# 00:57:16 [INFO] [stage1 590/760] 9338.png #590
# 00:57:16 [INFO] [stage1 590/760] 9338.png #590
# 00:58:00 [INFO] [stage1 600/760] 9338.png #600
# 00:58:00 [INFO] [stage1 600/760] 9338.png #600
# 00:58:43 [INFO] [stage1 610/760] 9338.png #610
# 00:58:43 [INFO] [stage1 610/760] 9338.png #610
# 00:59:26 [INFO] [stage1 620/760] 9338.png #620
# 00:59:26 [INFO] [stage1 620/760] 9338.png #620
# 01:00:08 [INFO] [stage1 630/760] 9338.png #630
# 01:00:08 [INFO] [stage1 630/760] 9338.png #630
# 01:00:48 [INFO] [stage1 640/760] 9338.png #640
# 01:00:48 [INFO] [stage1 640/760] 9338.png #640
# 01:01:28 [INFO] [stage1 650/760] 9338.png #650
# 01:01:28 [INFO] [stage1 650/760] 9338.png #650
# 01:02:11 [INFO] [stage1 660/760] 9338.png #660
# 01:02:11 [INFO] [stage1 660/760] 9338.png #660
# 01:02:54 [INFO] [stage1 670/760] 9338.png #670
# 01:02:54 [INFO] [stage1 670/760] 9338.png #670
# 01:03:37 [INFO] [stage1 680/760] 9338.png #680
# 01:03:37 [INFO] [stage1 680/760] 9338.png #680
# 01:04:19 [INFO] [stage1 690/760] 9338.png #690
# 01:04:19 [INFO] [stage1 690/760] 9338.png #690
# 01:04:58 [INFO] [stage1 700/760] 9338.png #700
# 01:04:58 [INFO] [stage1 700/760] 9338.png #700
# 01:05:37 [INFO] [stage1 710/760] 9338.png #710
# 01:05:37 [INFO] [stage1 710/760] 9338.png #710
# 01:06:17 [INFO] [stage1 720/760] 9338.png #720
# 01:06:17 [INFO] [stage1 720/760] 9338.png #720
# 01:06:55 [INFO] [stage1 730/760] 9338.png #730
# 01:06:55 [INFO] [stage1 730/760] 9338.png #730
# 01:07:34 [INFO] [stage1 740/760] 9338.png #740
# 01:07:34 [INFO] [stage1 740/760] 9338.png #740
# 01:08:13 [INFO] [stage1 750/760] 9338.png #750
# 01:08:13 [INFO] [stage1 750/760] 9338.png #750
# 01:08:52 [INFO] [stage1 760/760] 9338.png #760
# 01:08:52 [INFO] [stage1 760/760] 9338.png #760
# 01:08:56 [INFO] 9338.png selected for multi-seed: 56
# 01:08:56 [INFO] 9338.png selected for multi-seed: 56
# 01:08:56 [INFO] [validate 9338.png 01/56] cand 302 seed +1
# 01:08:56 [INFO] [validate 9338.png 01/56] cand 302 seed +1
# 01:09:00 [INFO] [validate 9338.png 01/56] cand 302 seed +2
# 01:09:00 [INFO] [validate 9338.png 01/56] cand 302 seed +2
# 01:09:04 [INFO] [validate 9338.png 01/56] cand 302 seed +3
# 01:09:04 [INFO] [validate 9338.png 01/56] cand 302 seed +3
# 01:09:08 [INFO] [validate 9338.png 02/56] cand 616 seed +1
# 01:09:08 [INFO] [validate 9338.png 02/56] cand 616 seed +1
# 01:09:11 [INFO] [validate 9338.png 02/56] cand 616 seed +2
# 01:09:11 [INFO] [validate 9338.png 02/56] cand 616 seed +2
# 01:09:15 [INFO] [validate 9338.png 02/56] cand 616 seed +3
# 01:09:15 [INFO] [validate 9338.png 02/56] cand 616 seed +3
# 01:09:19 [INFO] [validate 9338.png 03/56] cand 010 seed +1
# 01:09:19 [INFO] [validate 9338.png 03/56] cand 010 seed +1
# 01:09:23 [INFO] [validate 9338.png 03/56] cand 010 seed +2
# 01:09:23 [INFO] [validate 9338.png 03/56] cand 010 seed +2
# 01:09:27 [INFO] [validate 9338.png 03/56] cand 010 seed +3
# 01:09:27 [INFO] [validate 9338.png 03/56] cand 010 seed +3
# 01:09:30 [INFO] [validate 9338.png 04/56] cand 088 seed +1
# 01:09:30 [INFO] [validate 9338.png 04/56] cand 088 seed +1
# 01:09:34 [INFO] [validate 9338.png 04/56] cand 088 seed +2
# 01:09:34 [INFO] [validate 9338.png 04/56] cand 088 seed +2
# 01:09:38 [INFO] [validate 9338.png 04/56] cand 088 seed +3
# 01:09:38 [INFO] [validate 9338.png 04/56] cand 088 seed +3
# 01:09:42 [INFO] [validate 9338.png 05/56] cand 721 seed +1
# 01:09:42 [INFO] [validate 9338.png 05/56] cand 721 seed +1
# 01:09:46 [INFO] [validate 9338.png 05/56] cand 721 seed +2
# 01:09:46 [INFO] [validate 9338.png 05/56] cand 721 seed +2
# 01:09:50 [INFO] [validate 9338.png 05/56] cand 721 seed +3
# 01:09:50 [INFO] [validate 9338.png 05/56] cand 721 seed +3
# 01:09:53 [INFO] [validate 9338.png 06/56] cand 074 seed +1
# 01:09:53 [INFO] [validate 9338.png 06/56] cand 074 seed +1
# 01:09:57 [INFO] [validate 9338.png 06/56] cand 074 seed +2
# 01:09:57 [INFO] [validate 9338.png 06/56] cand 074 seed +2
# 01:10:01 [INFO] [validate 9338.png 06/56] cand 074 seed +3
# 01:10:01 [INFO] [validate 9338.png 06/56] cand 074 seed +3
# 01:10:05 [INFO] [validate 9338.png 07/56] cand 014 seed +1
# 01:10:05 [INFO] [validate 9338.png 07/56] cand 014 seed +1
# 01:10:09 [INFO] [validate 9338.png 07/56] cand 014 seed +2
# 01:10:09 [INFO] [validate 9338.png 07/56] cand 014 seed +2
# 01:10:13 [INFO] [validate 9338.png 07/56] cand 014 seed +3
# 01:10:13 [INFO] [validate 9338.png 07/56] cand 014 seed +3
# 01:10:17 [INFO] [validate 9338.png 08/56] cand 343 seed +1
# 01:10:17 [INFO] [validate 9338.png 08/56] cand 343 seed +1
# 01:10:21 [INFO] [validate 9338.png 08/56] cand 343 seed +2
# 01:10:21 [INFO] [validate 9338.png 08/56] cand 343 seed +2
# 01:10:25 [INFO] [validate 9338.png 08/56] cand 343 seed +3
# 01:10:25 [INFO] [validate 9338.png 08/56] cand 343 seed +3
# 01:10:29 [INFO] [validate 9338.png 09/56] cand 520 seed +1
# 01:10:29 [INFO] [validate 9338.png 09/56] cand 520 seed +1
# 01:10:33 [INFO] [validate 9338.png 09/56] cand 520 seed +2
# 01:10:33 [INFO] [validate 9338.png 09/56] cand 520 seed +2
# 01:10:37 [INFO] [validate 9338.png 09/56] cand 520 seed +3
# 01:10:37 [INFO] [validate 9338.png 09/56] cand 520 seed +3
# 01:10:41 [INFO] [validate 9338.png 10/56] cand 314 seed +1
# 01:10:41 [INFO] [validate 9338.png 10/56] cand 314 seed +1
# 01:10:46 [INFO] [validate 9338.png 10/56] cand 314 seed +2
# 01:10:46 [INFO] [validate 9338.png 10/56] cand 314 seed +2
# 01:10:50 [INFO] [validate 9338.png 10/56] cand 314 seed +3
# 01:10:50 [INFO] [validate 9338.png 10/56] cand 314 seed +3
# 01:10:54 [INFO] [validate 9338.png 11/56] cand 747 seed +1
# 01:10:54 [INFO] [validate 9338.png 11/56] cand 747 seed +1
# 01:10:58 [INFO] [validate 9338.png 11/56] cand 747 seed +2
# 01:10:58 [INFO] [validate 9338.png 11/56] cand 747 seed +2
# 01:11:02 [INFO] [validate 9338.png 11/56] cand 747 seed +3
# 01:11:02 [INFO] [validate 9338.png 11/56] cand 747 seed +3
# 01:11:06 [INFO] [validate 9338.png 12/56] cand 248 seed +1
# 01:11:06 [INFO] [validate 9338.png 12/56] cand 248 seed +1
# 01:11:10 [INFO] [validate 9338.png 12/56] cand 248 seed +2
# 01:11:10 [INFO] [validate 9338.png 12/56] cand 248 seed +2
# 01:11:14 [INFO] [validate 9338.png 12/56] cand 248 seed +3
# 01:11:14 [INFO] [validate 9338.png 12/56] cand 248 seed +3
# 01:11:18 [INFO] [validate 9338.png 13/56] cand 692 seed +1
# 01:11:18 [INFO] [validate 9338.png 13/56] cand 692 seed +1
# 01:11:22 [INFO] [validate 9338.png 13/56] cand 692 seed +2
# 01:11:22 [INFO] [validate 9338.png 13/56] cand 692 seed +2
# 01:11:26 [INFO] [validate 9338.png 13/56] cand 692 seed +3
# 01:11:26 [INFO] [validate 9338.png 13/56] cand 692 seed +3
# 01:11:31 [INFO] [validate 9338.png 14/56] cand 278 seed +1
# 01:11:31 [INFO] [validate 9338.png 14/56] cand 278 seed +1
# 01:11:35 [INFO] [validate 9338.png 14/56] cand 278 seed +2
# 01:11:35 [INFO] [validate 9338.png 14/56] cand 278 seed +2
# 01:11:39 [INFO] [validate 9338.png 14/56] cand 278 seed +3
# 01:11:39 [INFO] [validate 9338.png 14/56] cand 278 seed +3
# 01:11:43 [INFO] [validate 9338.png 15/56] cand 441 seed +1
# 01:11:43 [INFO] [validate 9338.png 15/56] cand 441 seed +1
# 01:11:47 [INFO] [validate 9338.png 15/56] cand 441 seed +2
# 01:11:47 [INFO] [validate 9338.png 15/56] cand 441 seed +2
# 01:11:51 [INFO] [validate 9338.png 15/56] cand 441 seed +3
# 01:11:51 [INFO] [validate 9338.png 15/56] cand 441 seed +3
# 01:11:55 [INFO] [validate 9338.png 16/56] cand 416 seed +1
# 01:11:55 [INFO] [validate 9338.png 16/56] cand 416 seed +1
# 01:11:59 [INFO] [validate 9338.png 16/56] cand 416 seed +2
# 01:11:59 [INFO] [validate 9338.png 16/56] cand 416 seed +2
# 01:12:03 [INFO] [validate 9338.png 16/56] cand 416 seed +3
# 01:12:03 [INFO] [validate 9338.png 16/56] cand 416 seed +3
# 01:12:07 [INFO] [validate 9338.png 17/56] cand 249 seed +1
# 01:12:07 [INFO] [validate 9338.png 17/56] cand 249 seed +1
# 01:12:11 [INFO] [validate 9338.png 17/56] cand 249 seed +2
# 01:12:11 [INFO] [validate 9338.png 17/56] cand 249 seed +2
# 01:12:16 [INFO] [validate 9338.png 17/56] cand 249 seed +3
# 01:12:16 [INFO] [validate 9338.png 17/56] cand 249 seed +3
# 01:12:20 [INFO] [validate 9338.png 18/56] cand 446 seed +1
# 01:12:20 [INFO] [validate 9338.png 18/56] cand 446 seed +1
# 01:12:24 [INFO] [validate 9338.png 18/56] cand 446 seed +2
# 01:12:24 [INFO] [validate 9338.png 18/56] cand 446 seed +2
# 01:12:28 [INFO] [validate 9338.png 18/56] cand 446 seed +3
# 01:12:28 [INFO] [validate 9338.png 18/56] cand 446 seed +3
# 01:12:32 [INFO] [validate 9338.png 19/56] cand 529 seed +1
# 01:12:32 [INFO] [validate 9338.png 19/56] cand 529 seed +1
# 01:12:35 [INFO] [validate 9338.png 19/56] cand 529 seed +2
# 01:12:35 [INFO] [validate 9338.png 19/56] cand 529 seed +2
# 01:12:39 [INFO] [validate 9338.png 19/56] cand 529 seed +3
# 01:12:39 [INFO] [validate 9338.png 19/56] cand 529 seed +3
# 01:12:43 [INFO] [validate 9338.png 20/56] cand 213 seed +1
# 01:12:43 [INFO] [validate 9338.png 20/56] cand 213 seed +1
# 01:12:46 [INFO] [validate 9338.png 20/56] cand 213 seed +2
# 01:12:46 [INFO] [validate 9338.png 20/56] cand 213 seed +2
# 01:12:50 [INFO] [validate 9338.png 20/56] cand 213 seed +3
# 01:12:50 [INFO] [validate 9338.png 20/56] cand 213 seed +3
# 01:12:54 [INFO] [validate 9338.png 21/56] cand 741 seed +1
# 01:12:54 [INFO] [validate 9338.png 21/56] cand 741 seed +1
# 01:12:57 [INFO] [validate 9338.png 21/56] cand 741 seed +2
# 01:12:57 [INFO] [validate 9338.png 21/56] cand 741 seed +2
# 01:13:01 [INFO] [validate 9338.png 21/56] cand 741 seed +3
# 01:13:01 [INFO] [validate 9338.png 21/56] cand 741 seed +3
# 01:13:05 [INFO] [validate 9338.png 22/56] cand 542 seed +1
# 01:13:05 [INFO] [validate 9338.png 22/56] cand 542 seed +1
# 01:13:09 [INFO] [validate 9338.png 22/56] cand 542 seed +2
# 01:13:09 [INFO] [validate 9338.png 22/56] cand 542 seed +2
# 01:13:13 [INFO] [validate 9338.png 22/56] cand 542 seed +3
# 01:13:13 [INFO] [validate 9338.png 22/56] cand 542 seed +3
# 01:13:17 [INFO] [validate 9338.png 23/56] cand 398 seed +1
# 01:13:17 [INFO] [validate 9338.png 23/56] cand 398 seed +1
# 01:13:21 [INFO] [validate 9338.png 23/56] cand 398 seed +2
# 01:13:21 [INFO] [validate 9338.png 23/56] cand 398 seed +2
# 01:13:24 [INFO] [validate 9338.png 23/56] cand 398 seed +3
# 01:13:24 [INFO] [validate 9338.png 23/56] cand 398 seed +3
# 01:13:28 [INFO] [validate 9338.png 24/56] cand 694 seed +1
# 01:13:28 [INFO] [validate 9338.png 24/56] cand 694 seed +1
# 01:13:32 [INFO] [validate 9338.png 24/56] cand 694 seed +2
# 01:13:32 [INFO] [validate 9338.png 24/56] cand 694 seed +2
# 01:13:36 [INFO] [validate 9338.png 24/56] cand 694 seed +3
# 01:13:36 [INFO] [validate 9338.png 24/56] cand 694 seed +3
# 01:13:39 [INFO] [validate 9338.png 25/56] cand 645 seed +1
# 01:13:39 [INFO] [validate 9338.png 25/56] cand 645 seed +1
# 01:13:43 [INFO] [validate 9338.png 25/56] cand 645 seed +2
# 01:13:43 [INFO] [validate 9338.png 25/56] cand 645 seed +2
# 01:13:47 [INFO] [validate 9338.png 25/56] cand 645 seed +3
# 01:13:47 [INFO] [validate 9338.png 25/56] cand 645 seed +3
# 01:13:51 [INFO] [validate 9338.png 26/56] cand 555 seed +1
# 01:13:51 [INFO] [validate 9338.png 26/56] cand 555 seed +1
# 01:13:55 [INFO] [validate 9338.png 26/56] cand 555 seed +2
# 01:13:55 [INFO] [validate 9338.png 26/56] cand 555 seed +2
# 01:13:59 [INFO] [validate 9338.png 26/56] cand 555 seed +3
# 01:13:59 [INFO] [validate 9338.png 26/56] cand 555 seed +3
# 01:14:03 [INFO] [validate 9338.png 27/56] cand 387 seed +1
# 01:14:03 [INFO] [validate 9338.png 27/56] cand 387 seed +1
# 01:14:07 [INFO] [validate 9338.png 27/56] cand 387 seed +2
# 01:14:07 [INFO] [validate 9338.png 27/56] cand 387 seed +2
# 01:14:10 [INFO] [validate 9338.png 27/56] cand 387 seed +3
# 01:14:10 [INFO] [validate 9338.png 27/56] cand 387 seed +3
# 01:14:14 [INFO] [validate 9338.png 28/56] cand 423 seed +1
# 01:14:14 [INFO] [validate 9338.png 28/56] cand 423 seed +1
# 01:14:18 [INFO] [validate 9338.png 28/56] cand 423 seed +2
# 01:14:18 [INFO] [validate 9338.png 28/56] cand 423 seed +2
# 01:14:22 [INFO] [validate 9338.png 28/56] cand 423 seed +3
# 01:14:22 [INFO] [validate 9338.png 28/56] cand 423 seed +3
# 01:14:26 [INFO] [validate 9338.png 29/56] cand 025 seed +1
# 01:14:26 [INFO] [validate 9338.png 29/56] cand 025 seed +1
# 01:14:29 [INFO] [validate 9338.png 29/56] cand 025 seed +2
# 01:14:29 [INFO] [validate 9338.png 29/56] cand 025 seed +2
# 01:14:34 [INFO] [validate 9338.png 29/56] cand 025 seed +3
# 01:14:34 [INFO] [validate 9338.png 29/56] cand 025 seed +3
# 01:14:37 [INFO] [validate 9338.png 30/56] cand 599 seed +1
# 01:14:37 [INFO] [validate 9338.png 30/56] cand 599 seed +1
# 01:14:41 [INFO] [validate 9338.png 30/56] cand 599 seed +2
# 01:14:41 [INFO] [validate 9338.png 30/56] cand 599 seed +2
# 01:14:45 [INFO] [validate 9338.png 30/56] cand 599 seed +3
# 01:14:45 [INFO] [validate 9338.png 30/56] cand 599 seed +3
# 01:14:49 [INFO] [validate 9338.png 31/56] cand 429 seed +1
# 01:14:49 [INFO] [validate 9338.png 31/56] cand 429 seed +1
# 01:14:52 [INFO] [validate 9338.png 31/56] cand 429 seed +2
# 01:14:52 [INFO] [validate 9338.png 31/56] cand 429 seed +2
# 01:14:56 [INFO] [validate 9338.png 31/56] cand 429 seed +3
# 01:14:56 [INFO] [validate 9338.png 31/56] cand 429 seed +3
# 01:15:00 [INFO] [validate 9338.png 32/56] cand 162 seed +1
# 01:15:00 [INFO] [validate 9338.png 32/56] cand 162 seed +1
# 01:15:04 [INFO] [validate 9338.png 32/56] cand 162 seed +2
# 01:15:04 [INFO] [validate 9338.png 32/56] cand 162 seed +2
# 01:15:08 [INFO] [validate 9338.png 32/56] cand 162 seed +3
# 01:15:08 [INFO] [validate 9338.png 32/56] cand 162 seed +3
# 01:15:12 [INFO] [validate 9338.png 33/56] cand 371 seed +1
# 01:15:12 [INFO] [validate 9338.png 33/56] cand 371 seed +1
# 01:15:15 [INFO] [validate 9338.png 33/56] cand 371 seed +2
# 01:15:15 [INFO] [validate 9338.png 33/56] cand 371 seed +2
# 01:15:19 [INFO] [validate 9338.png 33/56] cand 371 seed +3
# 01:15:19 [INFO] [validate 9338.png 33/56] cand 371 seed +3
# 01:15:23 [INFO] [validate 9338.png 34/56] cand 203 seed +1
# 01:15:23 [INFO] [validate 9338.png 34/56] cand 203 seed +1
# 01:15:27 [INFO] [validate 9338.png 34/56] cand 203 seed +2
# 01:15:27 [INFO] [validate 9338.png 34/56] cand 203 seed +2
# 01:15:31 [INFO] [validate 9338.png 34/56] cand 203 seed +3
# 01:15:31 [INFO] [validate 9338.png 34/56] cand 203 seed +3
# 01:15:35 [INFO] [validate 9338.png 35/56] cand 299 seed +1
# 01:15:35 [INFO] [validate 9338.png 35/56] cand 299 seed +1
# 01:15:39 [INFO] [validate 9338.png 35/56] cand 299 seed +2
# 01:15:39 [INFO] [validate 9338.png 35/56] cand 299 seed +2
# 01:15:43 [INFO] [validate 9338.png 35/56] cand 299 seed +3
# 01:15:43 [INFO] [validate 9338.png 35/56] cand 299 seed +3
# 01:15:47 [INFO] [validate 9338.png 36/56] cand 755 seed +1
# 01:15:47 [INFO] [validate 9338.png 36/56] cand 755 seed +1
# 01:15:51 [INFO] [validate 9338.png 36/56] cand 755 seed +2
# 01:15:51 [INFO] [validate 9338.png 36/56] cand 755 seed +2
# 01:15:55 [INFO] [validate 9338.png 36/56] cand 755 seed +3
# 01:15:55 [INFO] [validate 9338.png 36/56] cand 755 seed +3
# 01:15:59 [INFO] [validate 9338.png 37/56] cand 406 seed +1
# 01:15:59 [INFO] [validate 9338.png 37/56] cand 406 seed +1
# 01:16:03 [INFO] [validate 9338.png 37/56] cand 406 seed +2
# 01:16:03 [INFO] [validate 9338.png 37/56] cand 406 seed +2
# 01:16:07 [INFO] [validate 9338.png 37/56] cand 406 seed +3
# 01:16:07 [INFO] [validate 9338.png 37/56] cand 406 seed +3
# 01:16:11 [INFO] [validate 9338.png 38/56] cand 350 seed +1
# 01:16:11 [INFO] [validate 9338.png 38/56] cand 350 seed +1
# 01:16:15 [INFO] [validate 9338.png 38/56] cand 350 seed +2
# 01:16:15 [INFO] [validate 9338.png 38/56] cand 350 seed +2
# 01:16:19 [INFO] [validate 9338.png 38/56] cand 350 seed +3
# 01:16:19 [INFO] [validate 9338.png 38/56] cand 350 seed +3
# 01:16:23 [INFO] [validate 9338.png 39/56] cand 513 seed +1
# 01:16:23 [INFO] [validate 9338.png 39/56] cand 513 seed +1
# 01:16:27 [INFO] [validate 9338.png 39/56] cand 513 seed +2
# 01:16:27 [INFO] [validate 9338.png 39/56] cand 513 seed +2
# 01:16:31 [INFO] [validate 9338.png 39/56] cand 513 seed +3
# 01:16:31 [INFO] [validate 9338.png 39/56] cand 513 seed +3
# 01:16:35 [INFO] [validate 9338.png 40/56] cand 196 seed +1
# 01:16:35 [INFO] [validate 9338.png 40/56] cand 196 seed +1
# 01:16:40 [INFO] [validate 9338.png 40/56] cand 196 seed +2
# 01:16:40 [INFO] [validate 9338.png 40/56] cand 196 seed +2
# 01:16:44 [INFO] [validate 9338.png 40/56] cand 196 seed +3
# 01:16:44 [INFO] [validate 9338.png 40/56] cand 196 seed +3
# 01:16:48 [INFO] [validate 9338.png 41/56] cand 240 seed +1
# 01:16:48 [INFO] [validate 9338.png 41/56] cand 240 seed +1
# 01:16:52 [INFO] [validate 9338.png 41/56] cand 240 seed +2
# 01:16:52 [INFO] [validate 9338.png 41/56] cand 240 seed +2
# 01:16:56 [INFO] [validate 9338.png 41/56] cand 240 seed +3
# 01:16:56 [INFO] [validate 9338.png 41/56] cand 240 seed +3
# 01:17:00 [INFO] [validate 9338.png 42/56] cand 439 seed +1
# 01:17:00 [INFO] [validate 9338.png 42/56] cand 439 seed +1
# 01:17:04 [INFO] [validate 9338.png 42/56] cand 439 seed +2
# 01:17:04 [INFO] [validate 9338.png 42/56] cand 439 seed +2
# 01:17:08 [INFO] [validate 9338.png 42/56] cand 439 seed +3
# 01:17:08 [INFO] [validate 9338.png 42/56] cand 439 seed +3
# 01:17:12 [INFO] [validate 9338.png 43/56] cand 740 seed +1
# 01:17:12 [INFO] [validate 9338.png 43/56] cand 740 seed +1
# 01:17:16 [INFO] [validate 9338.png 43/56] cand 740 seed +2
# 01:17:16 [INFO] [validate 9338.png 43/56] cand 740 seed +2
# 01:17:21 [INFO] [validate 9338.png 43/56] cand 740 seed +3
# 01:17:21 [INFO] [validate 9338.png 43/56] cand 740 seed +3
# 01:17:25 [INFO] [validate 9338.png 44/56] cand 158 seed +1
# 01:17:25 [INFO] [validate 9338.png 44/56] cand 158 seed +1
# 01:17:29 [INFO] [validate 9338.png 44/56] cand 158 seed +2
# 01:17:29 [INFO] [validate 9338.png 44/56] cand 158 seed +2
# 01:17:32 [INFO] [validate 9338.png 44/56] cand 158 seed +3
# 01:17:32 [INFO] [validate 9338.png 44/56] cand 158 seed +3
# 01:17:37 [INFO] [validate 9338.png 45/56] cand 178 seed +1
# 01:17:37 [INFO] [validate 9338.png 45/56] cand 178 seed +1
# 01:17:41 [INFO] [validate 9338.png 45/56] cand 178 seed +2
# 01:17:41 [INFO] [validate 9338.png 45/56] cand 178 seed +2
# 01:17:45 [INFO] [validate 9338.png 45/56] cand 178 seed +3
# 01:17:45 [INFO] [validate 9338.png 45/56] cand 178 seed +3
# 01:17:48 [INFO] [validate 9338.png 46/56] cand 176 seed +1
# 01:17:48 [INFO] [validate 9338.png 46/56] cand 176 seed +1
# 01:17:52 [INFO] [validate 9338.png 46/56] cand 176 seed +2
# 01:17:52 [INFO] [validate 9338.png 46/56] cand 176 seed +2
# 01:17:56 [INFO] [validate 9338.png 46/56] cand 176 seed +3
# 01:17:56 [INFO] [validate 9338.png 46/56] cand 176 seed +3
# 01:18:00 [INFO] [validate 9338.png 47/56] cand 199 seed +1
# 01:18:00 [INFO] [validate 9338.png 47/56] cand 199 seed +1
# 01:18:04 [INFO] [validate 9338.png 47/56] cand 199 seed +2
# 01:18:04 [INFO] [validate 9338.png 47/56] cand 199 seed +2
# 01:18:08 [INFO] [validate 9338.png 47/56] cand 199 seed +3
# 01:18:08 [INFO] [validate 9338.png 47/56] cand 199 seed +3
# 01:18:12 [INFO] [validate 9338.png 48/56] cand 198 seed +1
# 01:18:12 [INFO] [validate 9338.png 48/56] cand 198 seed +1
# 01:18:16 [INFO] [validate 9338.png 48/56] cand 198 seed +2
# 01:18:16 [INFO] [validate 9338.png 48/56] cand 198 seed +2
# 01:18:20 [INFO] [validate 9338.png 48/56] cand 198 seed +3
# 01:18:20 [INFO] [validate 9338.png 48/56] cand 198 seed +3
# 01:18:24 [INFO] [validate 9338.png 49/56] cand 223 seed +1
# 01:18:24 [INFO] [validate 9338.png 49/56] cand 223 seed +1
# 01:18:28 [INFO] [validate 9338.png 49/56] cand 223 seed +2
# 01:18:28 [INFO] [validate 9338.png 49/56] cand 223 seed +2
# 01:18:32 [INFO] [validate 9338.png 49/56] cand 223 seed +3
# 01:18:32 [INFO] [validate 9338.png 49/56] cand 223 seed +3
# 01:18:35 [INFO] [validate 9338.png 50/56] cand 034 seed +1
# 01:18:35 [INFO] [validate 9338.png 50/56] cand 034 seed +1
# 01:18:39 [INFO] [validate 9338.png 50/56] cand 034 seed +2
# 01:18:39 [INFO] [validate 9338.png 50/56] cand 034 seed +2
# 01:18:43 [INFO] [validate 9338.png 50/56] cand 034 seed +3
# 01:18:43 [INFO] [validate 9338.png 50/56] cand 034 seed +3
# 01:18:47 [INFO] [validate 9338.png 51/56] cand 551 seed +1
# 01:18:47 [INFO] [validate 9338.png 51/56] cand 551 seed +1
# 01:18:51 [INFO] [validate 9338.png 51/56] cand 551 seed +2
# 01:18:51 [INFO] [validate 9338.png 51/56] cand 551 seed +2
# 01:18:55 [INFO] [validate 9338.png 51/56] cand 551 seed +3
# 01:18:55 [INFO] [validate 9338.png 51/56] cand 551 seed +3
# 01:18:59 [INFO] [validate 9338.png 52/56] cand 379 seed +1
# 01:18:59 [INFO] [validate 9338.png 52/56] cand 379 seed +1
# 01:19:03 [INFO] [validate 9338.png 52/56] cand 379 seed +2
# 01:19:03 [INFO] [validate 9338.png 52/56] cand 379 seed +2
# 01:19:07 [INFO] [validate 9338.png 52/56] cand 379 seed +3
# 01:19:07 [INFO] [validate 9338.png 52/56] cand 379 seed +3
# 01:19:11 [INFO] [validate 9338.png 53/56] cand 264 seed +1
# 01:19:11 [INFO] [validate 9338.png 53/56] cand 264 seed +1
# 01:19:15 [INFO] [validate 9338.png 53/56] cand 264 seed +2
# 01:19:15 [INFO] [validate 9338.png 53/56] cand 264 seed +2
# 01:19:20 [INFO] [validate 9338.png 53/56] cand 264 seed +3
# 01:19:20 [INFO] [validate 9338.png 53/56] cand 264 seed +3
# 01:19:24 [INFO] [validate 9338.png 54/56] cand 518 seed +1
# 01:19:24 [INFO] [validate 9338.png 54/56] cand 518 seed +1
# 01:19:28 [INFO] [validate 9338.png 54/56] cand 518 seed +2
# 01:19:28 [INFO] [validate 9338.png 54/56] cand 518 seed +2
# 01:19:32 [INFO] [validate 9338.png 54/56] cand 518 seed +3
# 01:19:32 [INFO] [validate 9338.png 54/56] cand 518 seed +3
# 01:19:35 [INFO] [validate 9338.png 55/56] cand 426 seed +1
# 01:19:35 [INFO] [validate 9338.png 55/56] cand 426 seed +1
# 01:19:39 [INFO] [validate 9338.png 55/56] cand 426 seed +2
# 01:19:39 [INFO] [validate 9338.png 55/56] cand 426 seed +2
# 01:19:43 [INFO] [validate 9338.png 55/56] cand 426 seed +3
# 01:19:43 [INFO] [validate 9338.png 55/56] cand 426 seed +3
# 01:19:47 [INFO] [validate 9338.png 56/56] cand 685 seed +1
# 01:19:47 [INFO] [validate 9338.png 56/56] cand 685 seed +1
# 01:19:51 [INFO] [validate 9338.png 56/56] cand 685 seed +2
# 01:19:51 [INFO] [validate 9338.png 56/56] cand 685 seed +2
# 01:19:55 [INFO] [validate 9338.png 56/56] cand 685 seed +3
# 01:19:55 [INFO] [validate 9338.png 56/56] cand 685 seed +3
# 01:20:25 [INFO] Wrote final robust top-k: c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2\TP2-students\students\outputs\20260603-001759_round40_9338_blend\top12_robust_fixed_seed.csv
# 01:20:25 [INFO] Wrote final robust top-k: c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2\TP2-students\students\outputs\20260603-001759_round40_9338_blend\top12_robust_fixed_seed.csv
# Finished successfully

# %% [markdown]
# ## Ver resultados

# %%
run_dirs = sorted(
    [path for path in OUTPUT_DIR.glob(f"*_{config['identity']}") if path.is_dir()],
    key=lambda path: path.stat().st_mtime,
    reverse=True,
)
if not run_dirs:
    print("No run directory found")
else:
    latest = run_dirs[0]
    print("Latest run:", latest)
    for item in sorted(latest.glob("*")):
        print(item.name)
# Out:
# Latest run: c:\Users\tugap\Desktop\Universidade\Masters2ºAno\IAG\ProjetoCunha\Projeto2\TP2-students\students\outputs\20260603-001759_round40_9338_blend
# 9338
# 9338_robust_prompt_ranking.csv
# 9338_selected_for_multiseed.csv
# 9338_stage1_fixed_seed_top40.csv
# contact_sheet_top12_robust.jpg
# stage1_fixed_seed_metrics.csv
# stage2_aux_seed_metrics.csv
# summary.json
# top12_robust_fixed_seed.csv
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
